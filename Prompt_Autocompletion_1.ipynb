# %%
# Colab deps
# !pip -q install --upgrade openai numpy scipy tqdm

import os, getpass, sys, json, random, re, time
import numpy as np
from dataclasses import dataclass
from collections import defaultdict, Counter
from tqdm import tqdm

# Set API key securely in Colab
if "OPENAI_API_KEY" not in os.environ:
    os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")

# OpenAI client (Responses API is the primary interface)
from openai import OpenAI
client = OpenAI()

# Model choice: use gpt-4o-mini to iterate, gpt-4o for strongest results
MODEL = "gpt-4o"  # change to "gpt-4o" later
TEMPERATURE = 0.2       # low temperature for style control

print("Ready. Model:", MODEL)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 1.1 MB/s eta 0:00:00
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/scipy/
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 64.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.5 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.5 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.3.5 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.5 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.5 which is incompatible.
# Enter your OpenAI API key: ··········
# Ready. Model: gpt-4o

# %%
def _safe_get_usage(usage):
    """
    Robustly extract token counts from Responses API usage object.
    Works whether attributes are present as fields or dict keys.
    """
    def g(obj, name):
        if obj is None: return None
        return getattr(obj, name, None) if not isinstance(obj, dict) else obj.get(name)

    it = g(usage, "input_tokens")
    ot = g(usage, "output_tokens")
    tt = g(usage, "total_tokens")

    # Fallbacks for older fields if present
    if it is None: it = g(usage, "prompt_tokens")
    if ot is None: ot = g(usage, "completion_tokens")
    if tt is None and it is not None and ot is not None: tt = it + ot
    if tt is None: tt = 0

    return {"input": it or 0, "output": ot or 0, "total": tt or 0}

def call_model(prompt, model=MODEL, temperature=TEMPERATURE, max_output_tokens=None):
    """
    One-shot text generation using Responses API.
    Returns text and token usage dict with input/output/total fields.
    """
    kwargs = dict(model=model, temperature=temperature)
    if max_output_tokens is not None:
        kwargs["max_output_tokens"] = max_output_tokens

    # You can send a single text string in 'input' for simple calls
    resp = client.responses.create(input=prompt, **kwargs)
    # Many SDKs expose a convenience property 'output_text'
    try:
        text = resp.output_text
    except Exception:
        # Fallback: join text segments if needed
        text = str(resp)

    usage = _safe_get_usage(getattr(resp, "usage", None))
    return (text or "").strip(), usage

def H_categorical(p):
    p = np.asarray(p, dtype=float); p = p / p.sum()
    nz = p[p > 0]
    return float(-(nz * np.log2(nz)).sum())

def KL(p, q):
    p = np.asarray(p, dtype=float); q = np.asarray(q, dtype=float)
    p = p / p.sum(); q = q / q.sum()
    mask = p > 0
    return float((p[mask] * np.log2(p[mask] / np.clip(q[mask], 1e-12, 1))).sum())

# %%
TONE   = ["formal", "friendly"]
LENGTH = ["short", "medium"]
FORMAT = ["bullets", "paragraph"]

@dataclass
class Task:
    name: str
    features: list
    U: dict  # hidden intent: tone/length/format

def make_tasks(n=20, seed=0):
    random.seed(seed)
    names = ["Stainless Steel Bottle", "88-Key MIDI Keyboard", "Trail Running Shoes",
             "Noise-Canceling Headphones", "Standing Desk Converter",
             "Smart LED Light Strip", "Mechanical Pencil Set", "Portable SSD 2TB",
             "Graph Paper Notebook", "Ergonomic Office Chair"]
    feats_pool = [
        ["insulated", "24 oz", "BPA-free"],
        ["semi-weighted keys", "USB-C bus powered", "DAW compatible"],
        ["rock plate", "breathable mesh", "4 mm drop"],
        ["ANC", "35h battery", "Bluetooth 5.3"],
        ["fits 13–27 inch monitors", "gas spring", "clamp or grommet"],
        ["16M colors", "music sync", "low power"],
        ["0.5 mm lead", "HB refills", "metal clip"],
        ["USB 3.2 gen 2", "up to 1000 MB/s", "aluminum shell"],
        ["A5", "100 gsm", "200 pages"],
        ["lumbar support", "tilt tension", "mesh back"],
    ]
    tasks = []
    for i in range(n):
        U = {"tone": random.choice(TONE), "length": random.choice(LENGTH), "format": random.choice(FORMAT)}
        tasks.append(Task(names[i % len(names)], feats_pool[i % len(feats_pool)], U))
    return tasks

def verify(output, task):
    ok = True; notes = []

    # content coverage: require each feature token to appear
    miss = [f for f in task.features if f.lower() not in output.lower()]
    if miss:
        ok = False; notes.append(f"Missing features: {miss}")

    # format check
    if task.U["format"] == "bullets":
        lines = [ln.strip() for ln in output.splitlines() if ln.strip()]
        bullet_like = sum(ln.startswith(("-", "*", "•")) for ln in lines) >= 2
        if not bullet_like:
            ok = False; notes.append("Expected bullet list.")
    else:
        if "\n-" in output or "\n*" in output or "\n•" in output:
            ok = False; notes.append("Expected paragraph, not bullets.")

    # length check
    wc = len(output.split())
    if task.U["length"] == "short" and wc > 70:
        ok = False; notes.append("Too long for 'short'.")
    if task.U["length"] == "medium" and not (70 <= wc <= 160):
        ok = False; notes.append("Out of 'medium' band.")

    return ok, notes

# %%
CLARIFY_QS = {
    "tone":   "Before I write, do you prefer a formal or friendly tone?",
    "length": "Do you want a short or a medium-length description?",
    "format": "Should I present it as bullet points or as a paragraph?"
}
VALUES = {"tone": TONE, "length": LENGTH, "format": FORMAT}

# For this simulation, the "user" answers truthfully at zero human latency.
# To keep the accounting realistic, we assign a tiny model-side cost per clarification.
CLARIFY_TOKEN_COST = 12  # tokens charged to the budget per clarification

def simulate_user_answer(var, U):
    return U[var]

def run_session_active(task, model=MODEL, epsilon_bits_per_token=0.01, max_clarifications=3):
    # Prior is uniform per attribute (factorized)
    q = {"tone":   np.ones(len(TONE))   / len(TONE),
         "length": np.ones(len(LENGTH)) / len(LENGTH),
         "format": np.ones(len(FORMAT)) / len(FORMAT)}

    asked = []
    total_tokens = 0
    dkl_bits_log = []

    for _ in range(max_clarifications):
        # Choose the attribute with the largest entropy per expected token
        candidates = [(var, H_categorical(q[var])) for var in q if var not in asked]
        if not candidates:
            break
        var, ent_bits = max(candidates, key=lambda kv: kv[1])

        # Stopping rule: if marginal info per token is too small, stop clarifying
        if ent_bits / CLARIFY_TOKEN_COST <= epsilon_bits_per_token:
            break

        # Ask and update (deterministic truthful answer)
        ans = simulate_user_answer(var, task.U)
        p_old = q[var].copy()
        post = np.zeros_like(q[var]); post[VALUES[var].index(ans)] = 1.0
        q[var] = post
        dkl_bits_log.append(KL(post, p_old))
        total_tokens += CLARIFY_TOKEN_COST
        asked.append(var)

    # Build final prompt from the current MAP style
    style = {k: VALUES[k][int(np.argmax(v))] for k, v in q.items()}

    sys = ("You are a concise marketing writer. Follow tone, format, and length exactly. "
           "Reuse the product features as-is.")
    instr = (f"Product: {task.name}\n"
             f"Features: {', '.join(task.features)}\n"
             f"Tone: {style['tone']}\nFormat: {style['format']}\nLength: {style['length']}\n"
             f"Write the description now.")
    prompt = f"[System]\n{sys}\n\n[User]\n{instr}"

    out, usage = call_model(prompt, model=model, temperature=0.2, max_output_tokens=220)
    total_tokens += usage["total"]

    ok, notes = verify(out, task)
    IE_1k = 1000.0 * (sum(dkl_bits_log) / max(total_tokens, 1))

    return {
        "asked": asked, "style": style, "output": out, "ok": ok, "notes": notes,
        "tokens": total_tokens, "IE_1k": IE_1k,
        "features": task.features, "truth_U": task.U
    }

def baseline_direct(task, model=MODEL):
    # No clarifications; fixed default style
    style = {"tone":"formal", "format":"paragraph", "length":"medium"}
    sys = ("You are a concise marketing writer. Follow tone, format, and length exactly. "
           "Reuse the product features as-is.")
    instr = (f"Product: {task.name}\n"
             f"Features: {', '.join(task.features)}\n"
             f"Tone: {style['tone']}\nFormat: {style['format']}\nLength: {style['length']}\n"
             f"Write the description now.")
    out, usage = call_model(f"[System]\n{sys}\n\n[User]\n{instr}", model=model, temperature=0.2, max_output_tokens=220)
    ok, notes = verify(out, task)
    return {"ok": ok, "tokens": usage["total"], "IE_1k": 0.0, "output": out}

# %%
# Build a small suite of tasks
tasks = make_tasks(n=12, seed=7)

# Active inference sessions
active_runs = [run_session_active(t, epsilon_bits_per_token=0.01, max_clarifications=3) for t in tqdm(tasks)]

# Baseline: direct generate with no clarifications
base_runs = [baseline_direct(t) for t in tqdm(tasks)]

def summarize(res):
    return {
        "compliance_rate": float(np.mean([r["ok"] for r in res])),
        "avg_tokens": float(np.mean([r["tokens"] for r in res])),
        "IE_1k_avg": float(np.mean([r["IE_1k"] for r in res])),
        "n": len(res),
    }

print("Active inference:", json.dumps(summarize(active_runs), indent=2))
print("Baseline direct:", json.dumps(summarize(base_runs), indent=2))
# Out:
# 100%|██████████| 12/12 [00:32<00:00,  2.71s/it]
# 100%|██████████| 12/12 [00:34<00:00,  2.88s/it]
# Active inference: {
#   "compliance_rate": 0.75,
#   "avg_tokens": 164.58333333333334,
#   "IE_1k_avg": 18.485424209444442,
#   "n": 12
# }
# Baseline direct: {
#   "compliance_rate": 0.08333333333333333,
#   "avg_tokens": 168.91666666666666,
#   "IE_1k_avg": 0.0,
#   "n": 12
# }

# %%
# Show one successful and one failed case for diagnostics
good = next((r for r in active_runs if r["ok"]), active_runs[0])
bad  = next((r for r in active_runs if not r["ok"]), active_runs[0])

def pretty_show(r):
    print("Truth U:", r["truth_U"], "| Asked:", r["asked"], "| Style used:", r["style"])
    print("Tokens:", r["tokens"], "| IE_1k:", f"{r['IE_1k']:.2f}", "| OK:", r["ok"])
    if r["notes"]:
        print("Verifier notes:", r["notes"])
    print("\n=== Output ===\n")
    print(r["output"][:1500])

print("=== Representative OK case ===")
pretty_show(good)
print("\n\n=== Representative non‑OK case ===")
pretty_show(bad)
# Out:
# === Representative OK case ===
# Truth U: {'tone': 'friendly', 'length': 'short', 'format': 'paragraph'} | Asked: ['tone', 'length', 'format'] | Style used: {'tone': 'friendly', 'length': 'short', 'format': 'paragraph'}
# Tokens: 159 | IE_1k: 18.87 | OK: True
#
# === Output ===
#
# Meet your new hydration hero! Our 24 oz Stainless Steel Bottle is insulated to keep your drinks at the perfect temperature, whether hot or cold. Plus, it's BPA-free, ensuring a safe sip every time. Stay refreshed and eco-friendly on the go!
#
#
# === Representative non‑OK case ===
# Truth U: {'tone': 'formal', 'length': 'short', 'format': 'bullets'} | Asked: ['tone', 'length', 'format'] | Style used: {'tone': 'formal', 'length': 'short', 'format': 'bullets'}
# Tokens: 148 | IE_1k: 20.27 | OK: False
# Verifier notes: ["Missing features: ['DAW compatible']"]
#
# === Output ===
#
# - Experience precision with semi-weighted keys for authentic touch.
# - Enjoy seamless connectivity with USB-C bus powered design.
# - Enhance your creativity with full DAW compatibility.

# %%
import matplotlib.pyplot as plt

acc_active = [1 if r["ok"] else 0 for r in active_runs]
tok_active = [r["tokens"] for r in active_runs]
ie_active  = [r["IE_1k"] for r in active_runs]

acc_base = [1 if r["ok"] else 0 for r in base_runs]
tok_base = [r["tokens"] for r in base_runs]

plt.figure()
plt.scatter(tok_active, acc_active, label="Active inference", alpha=0.8)
plt.scatter(tok_base,   acc_base,   label="Direct baseline", alpha=0.8)
plt.xlabel("Tokens per task")
plt.ylabel("Compliance (1=pass)")
plt.title("Compliance vs token cost")
plt.legend()
plt.show()

plt.figure()
plt.scatter(tok_active, ie_active, label="Active inference", alpha=0.8)
plt.xlabel("Tokens per task")
plt.ylabel("IE_1k (bits per kilotoken)")
plt.title("Information efficiency")
plt.legend()
plt.show()

# %%
# !pip -q install pandas
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np, random, math, json
from collections import defaultdict, Counter

# 1) Clarifier realism knobs
NOISY_CLARIFIER   = True     # add label noise to clarifying answers
EPS_NOISE         = 0.12     # P(answer is wrong) for each clarifying question
COST_SCHEDULE     = [24, 48, 72]  # token cost for the 1st/2nd/3rd clarification

# 2) Compliance weights (format matters more than tone in this toy)
WEIGHT = {"format": 1.0, "length": 0.6, "tone": 0.25}

def clarify_cost(k):
    """k is 1-based index of the clarification within a session."""
    return COST_SCHEDULE[min(k-1, len(COST_SCHEDULE)-1)]

def bayes_update_categorical(qvec, observed_idx, eps=EPS_NOISE):
    """
    Symmetric K-class noise model:
    P(ans | true=k) = 1-eps if ans=k, else eps/(K-1).
    """
    q = np.asarray(qvec, float); q = q / q.sum()
    K = len(q)
    like = np.full(K, eps / max(K-1, 1))
    like[observed_idx] = 1.0 - eps
    post = q * like
    post = post / post.sum()
    return post

def choose_attribute_entropy(q, asked, weight=None, next_cost=24):
    scores = {}
    for v in q:
        if v in asked:
            continue
        ent = H_categorical(q[v])
        w = 1.0 if weight is None else weight.get(v, 1.0)
        scores[v] = (w * ent) / max(next_cost, 1)
    if not scores:
        return None, 0.0
    var = max(scores, key=scores.get)
    return var, scores[var]

def run_session_policy(task, policy="active", epsilon_bits_per_token=0.02,
                       max_clarifications=3, weight=None, model=MODEL):
    """
    Returns a dict with step trace and summary fields.
    Policies:
      - "active"            : MI-per-token on entropy, uniform weights
      - "active_weighted"   : MI-per-token with compliance weights
      - "ask_all"           : ask all clarifications, then generate
      - "random"            : ask K~Uniform{0..max_clarifications}, random order
      - "baseline"          : zero clarifications
    """
    # Factorized prior over intent
    q = {"tone":   np.ones(len(TONE))   / len(TONE),
         "length": np.ones(len(LENGTH)) / len(LENGTH),
         "format": np.ones(len(FORMAT)) / len(FORMAT)}

    steps, asked = [], []
    # Decide target K for random policy
    K_rand = random.randint(0, max_clarifications) if policy == "random" else None
    remaining = ["tone", "length", "format"]

    # Clarification phase
    while True:
        if policy == "baseline":
            break
        if len(asked) >= max_clarifications:
            break
        if policy == "random" and len(asked) >= K_rand:
            break
        if policy == "ask_all":
            # pick any remaining attribute deterministically by name
            var = next((v for v in remaining if v not in asked), None)
            if var is None: break
            score = 1.0
        else:
            var, score = choose_attribute_entropy(q, asked,
                                                  weight if policy=="active_weighted" else None,
                                                  next_cost=clarify_cost(len(asked)+1))
            if var is None:
                break
            # stop rule for active policies
            if policy in {"active", "active_weighted"} and score <= epsilon_bits_per_token:
                break

        # Update with noisy or exact answer
        p_old = q[var].copy()
        obs_idx = VALUES[var].index(task.U[var])
        if NOISY_CLARIFIER:
            q[var] = bayes_update_categorical(q[var], obs_idx, eps=EPS_NOISE)
        else:
            post = np.zeros_like(q[var]); post[obs_idx] = 1.0
            q[var] = post

        dkl_bits = KL(q[var], p_old)
        ct = clarify_cost(len(asked)+1)
        steps.append({"type":"clarify", "var":var, "dkl_bits":float(dkl_bits), "tokens":int(ct)})
        asked.append(var)

    # Final generation
    style = {k: VALUES[k][int(np.argmax(v))] for k, v in q.items()}
    sys = ("You are a concise marketing writer. Follow tone, format, and length exactly. "
           "Reuse the product features as-is.")
    instr = (f"Product: {task.name}\n"
             f"Features: {', '.join(task.features)}\n"
             f"Tone: {style['tone']}\nFormat: {style['format']}\nLength: {style['length']}\n"
             f"Write the description now.")
    out, usage = call_model(f"[System]\n{sys}\n\n[User]\n{instr}",
                            model=model, temperature=0.2, max_output_tokens=220)
    steps.append({"type":"generate", "var":None, "dkl_bits":0.0, "tokens": int(usage["total"])})

    # Verify
    ok, notes = verify(out, task)

    # Summary
    bits_evidence = sum(s["dkl_bits"] for s in steps if s["type"]=="clarify")
    tok_evidence  = sum(s["tokens"]   for s in steps if s["type"]=="clarify")
    tok_total     = sum(s["tokens"]   for s in steps)

    IE_1k_evidence = 1000.0 * bits_evidence / max(tok_evidence, 1)
    IE_1k_session  = 1000.0 * bits_evidence / max(tok_total, 1)

    # Failure type tags
    ftypes = []
    for n in notes:
        s = n.lower()
        if "missing features" in s: ftypes.append("content")
        if "expected bullet" in s or "paragraph" in s: ftypes.append("format")
        if "long" in s or "medium" in s: ftypes.append("length")
    if not ftypes and not ok:
        ftypes = ["other"]

    # Store marginal bits per clarification index
    marg_bits = [s["dkl_bits"] for s in steps if s["type"]=="clarify"]
    while len(marg_bits) < 3:
        marg_bits.append(np.nan)

    return {
        "policy": policy, "ok": int(ok),
        "clarifications": len(asked),
        "tokens_total": tok_total, "tokens_evidence": tok_evidence,
        "IE_1k_session": IE_1k_session, "IE_1k_evidence": IE_1k_evidence,
        "mbit_1": marg_bits[0], "mbit_2": marg_bits[1], "mbit_3": marg_bits[2],
        "fail_types": ftypes, "notes": notes, "style_used": style, "truth_U": task.U,
        "steps": steps, "output": out
    }

# %%
# More tasks for dense plots. Increase with care since each task generates once.
N_TASKS = 48
tasks = make_tasks(n=N_TASKS, seed=42)

POLICIES = [
    ("active", {"epsilon_bits_per_token": 0.02, "max_clarifications": 3}),
    ("active_weighted", {"epsilon_bits_per_token": 0.02, "max_clarifications": 3}),
    ("ask_all", {"max_clarifications": 3}),
    ("random", {"max_clarifications": 3}),
    ("baseline", {})
]

rows = []
for name, cfg in POLICIES:
    for i, t in enumerate(tqdm(tasks, desc=f"Policy={name}")):
        res = run_session_policy(
            t,
            policy=name,
            epsilon_bits_per_token=cfg.get("epsilon_bits_per_token", 0.0),
            max_clarifications=cfg.get("max_clarifications", 0),
            weight=WEIGHT if name=="active_weighted" else None,
            model=MODEL
        )
        res["task_id"] = i
        rows.append(res)

df = pd.DataFrame(rows)
df.head()
# Out:
# Policy=active: 100%|██████████| 48/48 [02:01<00:00,  2.52s/it]
# Policy=active_weighted: 100%|██████████| 48/48 [01:54<00:00,  2.38s/it]
# Policy=ask_all: 100%|██████████| 48/48 [01:57<00:00,  2.45s/it]
# Policy=random: 100%|██████████| 48/48 [01:59<00:00,  2.49s/it]
# Policy=baseline: 100%|██████████| 48/48 [01:50<00:00,  2.31s/it]
#    policy  ok  clarifications  tokens_total  tokens_evidence  IE_1k_session  \
# 0  active   0               2           175               72       5.378733
# 1  active   0               2           191               72       4.928158
# 2  active   0               2           181               72       5.200432
# 3  active   0               2           189               72       4.980308
# 4  active   0               2           186               72       5.060636
#
#    IE_1k_evidence    mbit_1    mbit_2  mbit_3 fail_types  \
# 0       13.073309  0.470639  0.470639     NaN   [format]
# 1       13.073309  0.470639  0.470639     NaN  [content]
# 2       13.073309  0.470639  0.470639     NaN   [format]
# 3       13.073309  0.470639  0.470639     NaN  [content]
# 4       13.073309  0.470639  0.470639     NaN  [content]
#
#                                               notes  \
# 0                [Expected paragraph, not bullets.]
# 1            [Missing features: ['DAW compatible']]
# 2                [Expected paragraph, not bullets.]
# 3               [Missing features: ['35h battery']]
# 4  [Missing features: ['fits 13–27 inch monitors']]
#
#                                           style_used  \
# 0  {'tone': 'formal', 'length': 'short', 'format'...
# 1  {'tone': 'formal', 'length': 'short', 'format'...
# 2  {'tone': 'formal', 'length': 'short', 'format'...
# 3  {'tone': 'formal', 'length': 'short', 'format'...
# 4  {'tone': 'formal', 'length': 'short', 'format'...
#
#                                              truth_U  \
# 0  {'tone': 'formal', 'length': 'short', 'format'...
# 1  {'tone': 'formal', 'length': 'short', 'format'...
# 2  {'tone': 'formal', 'length': 'short', 'format'...
# 3  {'tone': 'formal', 'length': 'short', 'format'...
# 4  {'tone': 'formal', 'length': 'short', 'format'...
#
#                                                steps  \
# 0  [{'type': 'clarify', 'var': 'tone', 'dkl_bits'...
# 1  [{'type': 'clarify', 'var': 'tone', 'dkl_bits'...
# 2  [{'type': 'clarify', 'var': 'tone', 'dkl_bits'...
# 3  [{'type': 'clarify', 'var': 'tone', 'dkl_bits'...
# 4  [{'type': 'clarify', 'var': 'tone', 'dkl_bits'...
#
#                                               output  task_id
# 0  - Premium stainless steel construction\n- Insu...        0
# 1  - Experience precision with **semi-weighted ke...        1
# 2  - Equipped with a durable rock plate for enhan...        2
# 3  - Advanced Active Noise Cancellation (ANC) for...        3
# 4  - Accommodates 13–27 inch monitors for versati...        4

# %%
plt.rcParams.update({"figure.figsize": (7.0, 5.0)})

def agg(df, by="policy"):
    g = df.groupby(by)
    return g["ok"].mean(), g["tokens_total"].mean(), g["tokens_total"].std()/np.sqrt(g.size()), g.size()

policies = df["policy"].unique().tolist()
colors = {p: c for p,c in zip(policies, plt.cm.tab10.colors[:len(policies)])}

# 1) Efficiency frontier: compliance vs average tokens with error bars
acc, tok_mean, tok_sem, n = agg(df)
plt.figure()
for p in policies:
    x = tok_mean[p]; y = acc[p]
    plt.errorbar(x, y, xerr=tok_sem[p], fmt="o", color=colors[p], capsize=3)
    plt.text(x+2, y, f"{p} (n={n[p]})", fontsize=9, color=colors[p])
plt.xlabel("Average tokens per task")
plt.ylabel("Compliance rate")
plt.title("Efficiency frontier")
plt.ylim(-0.02, 1.05)
plt.grid(True, alpha=0.25)
plt.show()

# 2) ECDF of tokens per task
def ecdf(x):
    x = np.sort(np.asarray(x))
    y = np.arange(1, len(x)+1) / len(x)
    return x, y

plt.figure()
for p in policies:
    xs, ys = ecdf(df.loc[df.policy==p, "tokens_total"])
    plt.plot(xs, ys, label=p, color=colors[p])
plt.xlabel("Tokens per task")
plt.ylabel("ECDF")
plt.title("Token cost distribution")
plt.legend()
plt.grid(True, alpha=0.25)
plt.show()

# 3) Distribution of number of clarifications
plt.figure()
bins = np.arange(-0.5, 4.5, 1.0)
width = 0.18
for j,p in enumerate(policies):
    counts, _ = np.histogram(df.loc[df.policy==p, "clarifications"], bins=bins)
    centers = np.arange(0, 4)
    plt.bar(centers + (j - len(policies)/2)*width + width/2, counts, width=width, label=p, color=colors[p])
plt.xticks([0,1,2,3], ["0","1","2","3"])
plt.xlabel("Clarifications used")
plt.ylabel("Count")
plt.title("How many clarifications each policy uses")
plt.legend()
plt.show()

# 4) IE_1k boxplot by policy
plt.figure()
data = [df.loc[df.policy==p, "IE_1k_session"].dropna().values for p in policies]
plt.boxplot(data, labels=policies, showmeans=True)
plt.ylabel("IE_1k (bits per kilotoken)")
plt.title("Information efficiency across policies")
plt.grid(True, axis="y", alpha=0.25)
plt.show()

# 5) Marginal information per clarification index, mean with 95% CI
plt.figure()
ks = [1,2,3]
for p in policies:
    means, lows, highs = [], [], []
    for k in ks:
        col = f"mbit_{k}"
        vals = df.loc[df.policy==p, col].dropna().values
        if len(vals) == 0:
            means.append(np.nan); lows.append(np.nan); highs.append(np.nan)
        else:
            m = np.mean(vals); s = np.std(vals, ddof=1) / np.sqrt(len(vals))
            means.append(m)
            lows.append(m - 1.96*s); highs.append(m + 1.96*s)
    plt.plot(ks, means, marker="o", color=colors[p], label=p)
    for k, lo, hi in zip(ks, lows, highs):
        if not np.isnan(lo):
            plt.fill_between([k-0.1, k+0.1], [lo, lo], [hi, hi], color=colors[p], alpha=0.2)
plt.xticks(ks, ["1st","2nd","3rd"])
plt.xlabel("Clarification index")
plt.ylabel("Marginal bits (KL)")
plt.title("Diminishing returns of clarifications")
plt.legend()
plt.grid(True, alpha=0.25)
plt.show()

# 6) Failure types stacked bar chart
fail_counts = {p: Counter() for p in policies}
for _, row in df.iterrows():
    if row["ok"] == 0:
        for t in row["fail_types"]:
            fail_counts[row["policy"]][t] += 1

cats = ["content","format","length","other"]
plt.figure()
bottom = np.zeros(len(policies))
for cat in cats:
    vals = np.array([fail_counts[p][cat] for p in policies])
    plt.bar(policies, vals, bottom=bottom, label=cat)
    bottom += vals
plt.ylabel("Failures")
plt.title("Why outputs failed (verifier categories)")
plt.legend()
plt.show()

# 7) Per-session timeline: tokens vs cumulative and IE_1k curve for a representative run
def timeline_plot(row, title="Session timeline"):
    steps = row["steps"]
    # Build cumulative tokens and IE_1k curve
    cum_tokens, cum_bits, cur = [], 0.0, 0
    ie_curve = []
    for s in steps:
        cur += s["tokens"]
        if s["type"]=="clarify":
            cum_bits += s["dkl_bits"]
        ie_curve.append(1000.0 * cum_bits / max(cur, 1))
        cum_tokens.append(cur)

    fig, ax1 = plt.subplots(figsize=(7,3.8))
    ax1.bar(range(1, len(steps)+1),
            [s["tokens"] for s in steps],
            color=["#5DA5DA" if s["type"]=="clarify" else "#F15854" for s in steps])
    ax1.set_xlabel("Step index")
    ax1.set_ylabel("Tokens at step")
    ax1.set_title(title)

    ax2 = ax1.twinx()
    ax2.plot(range(1, len(steps)+1), ie_curve, marker="o", color="#60BD68")
    ax2.set_ylabel("IE_1k (cumulative)")
    ax1.grid(True, axis="y", alpha=0.25)
    plt.show()

# Pick one success and one failure per policy (if available)
for p in policies:
    dfp = df[df.policy==p]
    row_ok  = dfp[dfp.ok==1].head(1)
    row_bad = dfp[dfp.ok==0].head(1)
    if len(row_ok):
        timeline_plot(row_ok.iloc[0], f"{p}: representative success")
    if len(row_bad):
        timeline_plot(row_bad.iloc[0], f"{p}: representative failure")
# Out:
# /tmp/ipython-input-1591899041.py:59: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=policies, showmeans=True)

# %%
# Cell 10: Bilevel optimization over clarification threshold and budget

# Training and test sets for outer loop
N_TASKS_TRAIN = 24
N_TASKS_TEST  = 24

tasks_train = make_tasks(n=N_TASKS_TRAIN, seed=100)
tasks_test  = make_tasks(n=N_TASKS_TEST,  seed=101)

# Tradeoff coefficient: how much we penalize tokens relative to compliance
# Units: J = E[ok] - lambda_cost * (E[tokens_total] / 1000)
lambda_cost = 0.02

eps_grid = [0.0, 0.005, 0.01, 0.02, 0.04]
max_clar_grid = [1, 2, 3]

outer_records = []

for eps in eps_grid:
    for mc in max_clar_grid:
        rows_cfg = []
        desc = f"train active_mi_weighted eps={eps:.3f}, K={mc}"
        for i, t in enumerate(tqdm(tasks_train, desc=desc)):
            res = run_session_policy(
                t,
                policy="active_mi_weighted",
                epsilon_bits_per_token=eps,
                max_clarifications=mc,
                weight=WEIGHT,
                model=MODEL,
            )
            res["config_eps"] = eps
            res["config_max_clar"] = mc
            rows_cfg.append(res)

        df_cfg = pd.DataFrame(rows_cfg)
        E_ok = df_cfg["ok"].mean()
        E_tokens = df_cfg["tokens_total"].mean()
        E_clar = df_cfg["clarifications"].mean()
        J = float(E_ok - lambda_cost * (E_tokens / 1000.0))

        outer_records.append({
            "epsilon": eps,
            "max_clarifications": mc,
            "E_ok_train": float(E_ok),
            "E_tokens_train": float(E_tokens),
            "E_clar_train": float(E_clar),
            "J_train": J,
        })

outer_df = pd.DataFrame(outer_records).sort_values("J_train", ascending=False)
print("Top hyperparameter settings on the training set (sorted by J):")
outer_df.head(10)
# Out:
# train active_mi_weighted eps=0.000, K=1: 100%|██████████| 24/24 [01:00<00:00,  2.53s/it]
# train active_mi_weighted eps=0.000, K=2: 100%|██████████| 24/24 [00:56<00:00,  2.36s/it]
# train active_mi_weighted eps=0.000, K=3: 100%|██████████| 24/24 [01:04<00:00,  2.68s/it]
# train active_mi_weighted eps=0.005, K=1: 100%|██████████| 24/24 [00:55<00:00,  2.30s/it]
# train active_mi_weighted eps=0.005, K=2: 100%|██████████| 24/24 [00:58<00:00,  2.43s/it]
# train active_mi_weighted eps=0.005, K=3: 100%|██████████| 24/24 [01:01<00:00,  2.57s/it]
# train active_mi_weighted eps=0.010, K=1: 100%|██████████| 24/24 [00:55<00:00,  2.31s/it]
# train active_mi_weighted eps=0.010, K=2: 100%|██████████| 24/24 [00:58<00:00,  2.45s/it]
# train active_mi_weighted eps=0.010, K=3: 100%|██████████| 24/24 [01:00<00:00,  2.53s/it]
# train active_mi_weighted eps=0.020, K=1: 100%|██████████| 24/24 [00:55<00:00,  2.33s/it]
# train active_mi_weighted eps=0.020, K=2: 100%|██████████| 24/24 [00:57<00:00,  2.42s/it]
# train active_mi_weighted eps=0.020, K=3: 100%|██████████| 24/24 [00:59<00:00,  2.48s/it]
# train active_mi_weighted eps=0.040, K=1: 100%|██████████| 24/24 [00:54<00:00,  2.28s/it]
# train active_mi_weighted eps=0.040, K=2: 100%|██████████| 24/24 [00:55<00:00,  2.31s/it]
# train active_mi_weighted eps=0.040, K=3: 100%|██████████| 24/24 [00:57<00:00,  2.40s/it]
# Top hyperparameter settings on the training set (sorted by J):
#     epsilon  max_clarifications  E_ok_train  E_tokens_train  E_clar_train  \
# 11    0.020                   3    0.625000      293.333333           3.0
# 5     0.005                   3    0.541667      291.333333           3.0
# 14    0.040                   3    0.541667      292.208333           3.0
# 8     0.010                   3    0.541667      294.666667           3.0
# 2     0.000                   3    0.500000      290.625000           3.0
# 13    0.040                   2    0.291667      204.875000           2.0
# 1     0.000                   2    0.291667      206.916667           2.0
# 10    0.020                   2    0.291667      209.000000           2.0
# 9     0.020                   1    0.250000      136.916667           1.0
# 12    0.040                   1    0.250000      137.375000           1.0
#
#      J_train
# 11  0.619133
# 5   0.535840
# 14  0.535822
# 8   0.535773
# 2   0.494188
# 13  0.287569
# 1   0.287528
# 10  0.287487
# 9   0.247262
# 12  0.247252

# %%
# Cell 11: Evaluate best configuration on a held out test set

best = outer_df.iloc[0]
best_eps = float(best["epsilon"])
best_mc  = int(best["max_clarifications"])

print("Best configuration from training:")
print(best)

# Evaluate active_mi_weighted with best hyperparameters on test tasks
rows_test_best = []
for i, t in enumerate(tqdm(tasks_test, desc="Best config on test")):
    res = run_session_policy(
        t,
        policy="active_mi_weighted",
        epsilon_bits_per_token=best_eps,
        max_clarifications=best_mc,
        weight=WEIGHT,
        model=MODEL,
    )
    rows_test_best.append(res)
df_test_best = pd.DataFrame(rows_test_best)

# Evaluate a baseline with no clarifications on test tasks
rows_test_base = []
for i, t in enumerate(tqdm(tasks_test, desc="Baseline on test")):
    res = run_session_policy(
        t,
        policy="baseline",
        epsilon_bits_per_token=0.0,
        max_clarifications=0,
        weight=None,
        model=MODEL,
    )
    rows_test_base.append(res)
df_test_base = pd.DataFrame(rows_test_base)

summary_test = {
    "active_mi_weighted": {
        "E_ok": float(df_test_best["ok"].mean()),
        "E_tokens": float(df_test_best["tokens_total"].mean()),
        "E_clar": float(df_test_best["clarifications"].mean()),
    },
    "baseline": {
        "E_ok": float(df_test_base["ok"].mean()),
        "E_tokens": float(df_test_base["tokens_total"].mean()),
        "E_clar": float(df_test_base["clarifications"].mean()),
    },
}

print("Test set comparison (best active policy vs baseline):")
print(json.dumps(summary_test, indent=2))
# Out:
# Best configuration from training:
# epsilon                 0.020000
# max_clarifications      3.000000
# E_ok_train              0.625000
# E_tokens_train        293.333333
# E_clar_train            3.000000
# J_train                 0.619133
# Name: 11, dtype: float64
# Best config on test: 100%|██████████| 24/24 [01:03<00:00,  2.66s/it]
# Baseline on test: 100%|██████████| 24/24 [00:53<00:00,  2.25s/it]
# Test set comparison (best active policy vs baseline):
# {
#   "active_mi_weighted": {
#     "E_ok": 0.4583333333333333,
#     "E_tokens": 295.875,
#     "E_clar": 3.0
#   },
#   "baseline": {
#     "E_ok": 0.041666666666666664,
#     "E_tokens": 110.54166666666667,
#     "E_clar": 0.0
#   }
# }
